# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
counter_word=Counter(int_words)

# %%
def subsample(int_words,int_to_vocab,t):
    prob={}
    train_words=[]
    for i in int_to_vocab.keys():
        frequency=counter_word[i]/len(int_words)
        if frequency<=t:
            prob[i]=0
        else:
            prob[i]=1.0-np.sqrt(t/frequency)
    for _,word in enumerate(int_words):
        if np.random.binomial(1,prob[word])==0:
            train_words.append(word)
    return train_words

# %%
train_words=subsample(int_words,int_to_vocab,1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    Target=[]
    width=np.random.randint(1,6)
    first_target=words[(idx-width):idx]
    second_target=words[idx+1:(idx+width+1)]
    Target.extend(first_target)
    Target.extend(second_target)
    
    
    
    return Target

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
tf.reset_default_graph()

train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='Inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300# Number of embedding features 
with train_graph.as_default():
    embedding =tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1,1)) # create embedding weight matrix here
    embed =tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab,n_embedding]))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,
                                     labels,embed,
                                     n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 21.6175 0.2013 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 21.4191 0.1765 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 21.1561 0.1754 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 21.1185 0.1724 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 20.8647 0.1742 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 20.7585 0.1758 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 20.5434 0.1747 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 20.5244 0.1751 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 20.2911 0.1752 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 20.2155 0.1742 sec/batch
# Nearest to nine: nurse, ludwig, bataan, mullin, rapeseed, adh, completeness, nosed,
# Nearest to who: rudimentary, merlin, sniper, humphries, limericks, acheson, yah, boudinot,
# Nearest to be: imre, flattened, ears, sanjo, gotta, mitigated, mantra, trofim,
# Nearest to over: digger, marianne, bulky, raoul, allergic, heretical, rays, lavender,
# Nearest to called: although, reichsf, hadrian, substitutions, warms, pfalz, faqs, myth,
# Nearest to where: wonders, seagulls, insolence, gales, aph, searing, haystack, mirage,
# Nearest to has: weu, graceful, contraction, basquiat, konstantin, understudy, gus, documentaries,
# Nearest to may: quezon, odd, miniseries, pliny, programme, hypermedia, trabajo, peasants,
# Nearest to test: cali, signatories, chappell, adversity, khanates, varanus, jug, farian,
# Nearest to police: unfaithful, headhunters, despot, augustinian, tarot, dagan, germany, regrowth,
# Nearest to square: white, brixton, practitioners, abuses, bfa, melodramatic, infrequently, anduin,
# Nearest to behind: exemplifies, hyena, automaticity, tch, chancellors, exterminated, majed, noam,
# Nearest to resources: maldivian, heine, judean, malicious, virtually, arson, wars, cumming,
# Nearest to hold: testa, proc, prescription, comprehensible, altruism, untrained, apotheosis, clinic,
# Nearest to something: aerobics, kingsley, venn, vibrating, sunderland, repairs, uniqueness, acclaim,
# Nearest to engineering: wintour, bornholm, sandow, bolden, footprints, cooke, cubism, officialdom,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 20.1296 0.1760 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 19.9798 0.1744 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 19.9081 0.1749 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 19.7526 0.1753 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 19.6420 0.1750 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 19.5507 0.1755 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 19.4177 0.1750 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 19.2756 0.1757 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 19.1388 0.1753 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 19.1344 0.1767 sec/batch
# Nearest to nine: ludwig, nurse, mullin, bataan, adh, nosed, completeness, westwood,
# Nearest to who: rudimentary, merlin, humphries, sniper, uns, khrushchev, acheson, boudinot,
# Nearest to be: imre, flattened, sanjo, ears, gotta, mitigated, trofim, risc,
# Nearest to over: digger, marianne, bulky, raoul, allergic, amakusa, doric, perceiving,
# Nearest to called: although, reichsf, hadrian, substitutions, warms, faqs, pfalz, petrograd,
# Nearest to where: wonders, seagulls, insolence, haystack, searing, mirage, aph, pdp,
# Nearest to has: weu, graceful, contraction, basquiat, konstantin, misrepresenting, etcetera, understudy,
# Nearest to may: quezon, miniseries, odd, programme, pliny, peasants, trabajo, hypermedia,
# Nearest to test: cali, signatories, chappell, adversity, khanates, jug, bildungsroman, varanus,
# Nearest to police: unfaithful, headhunters, despot, augustinian, germany, dagan, ventricular, tarot,
# Nearest to square: white, abuses, practitioners, brixton, bfa, melodramatic, arnaz, infrequently,
# Nearest to behind: exemplifies, hyena, automaticity, tch, chancellors, noam, exterminated, contractile,
# Nearest to resources: heine, maldivian, malicious, virtually, judean, arson, wars, medication,
# Nearest to hold: testa, proc, prescription, altruism, untrained, comprehensible, apotheosis, clinic,
# Nearest to something: aerobics, kingsley, venn, vibrating, sunderland, dvds, measurable, acclaim,
# Nearest to engineering: wintour, bornholm, sandow, footprints, bolden, cubism, cooke, troyes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 18.8892 0.1765 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 18.8249 0.1754 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 18.7708 0.1756 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 18.6563 0.1763 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 18.5597 0.1757 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 18.3841 0.1759 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 18.2569 0.1765 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 18.2677 0.1758 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 18.1275 0.1754 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 18.0456 0.1767 sec/batch
# Nearest to nine: ludwig, nurse, bataan, adh, mullin, westwood, farnell, jabberwocky,
# Nearest to who: sniper, rudimentary, uns, merlin, humphries, khrushchev, acheson, repurchase,
# Nearest to be: imre, flattened, sanjo, ears, trofim, risc, mantra, fantasy,
# Nearest to over: digger, marianne, raoul, bulky, allergic, amakusa, perceiving, closeted,
# Nearest to called: although, reichsf, hadrian, faqs, pfalz, warms, petrograd, gregorio,
# Nearest to where: wonders, insolence, seagulls, haystack, searing, aph, bookkeeping, pdp,
# Nearest to has: weu, graceful, contraction, basquiat, suez, etcetera, konstantin, misrepresenting,
# Nearest to may: quezon, programme, peasants, miniseries, odd, hypermedia, surprise, revamped,
# Nearest to test: cali, chappell, signatories, adversity, jug, varanus, khanates, bildungsroman,
# Nearest to police: unfaithful, headhunters, despot, augustinian, germany, prosecutorial, dagan, ventricular,
# Nearest to square: white, practitioners, brixton, abuses, melodramatic, bfa, arnaz, anduin,
# Nearest to behind: exemplifies, noam, hyena, tch, automaticity, chancellors, exterminated, reception,
# Nearest to resources: heine, virtually, malicious, maldivian, wars, judean, medication, arson,
# Nearest to hold: testa, proc, prescription, comprehensible, altruism, giza, apotheosis, untrained,
# Nearest to something: aerobics, kingsley, vibrating, venn, cations, measurable, renouf, sunderland,
# Nearest to engineering: wintour, bornholm, footprints, bolden, sandow, cubism, cooke, denoting,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 18.0099 0.1779 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 17.8232 0.1761 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 17.6750 0.1760 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 17.6456 0.1772 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 17.5282 0.1788 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 17.4544 0.1765 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 17.3859 0.1774 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 17.2732 0.1757 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 17.1663 0.1768 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 17.0458 0.1760 sec/batch
# Nearest to nine: nurse, ludwig, adh, westwood, bataan, jabberwocky, doctors, matured,
# Nearest to who: uns, judaean, merlin, sniper, rudimentary, boudinot, repurchase, acheson,
# Nearest to be: imre, sanjo, flattened, ears, trofim, gotta, mantra, fantasy,
# Nearest to over: digger, marianne, raoul, bulky, amakusa, allergic, perceiving, bennie,
# Nearest to called: although, reichsf, faqs, hadrian, warms, pfalz, substitutions, ecclesiastical,
# Nearest to where: wonders, insolence, seagulls, haystack, bookkeeping, gunmen, searing, shamrock,
# Nearest to has: weu, graceful, contraction, basquiat, escort, suez, etcetera, pinocchio,
# Nearest to may: quezon, programme, peasants, odd, miniseries, revamped, trabajo, hypermedia,
# Nearest to test: cali, signatories, adversity, chappell, jug, khanates, varanus, barges,
# Nearest to police: unfaithful, headhunters, despot, augustinian, dagan, bioprospecting, tarot, germany,
# Nearest to square: white, practitioners, abuses, brixton, bfa, melodramatic, tip, arnaz,
# Nearest to behind: exemplifies, noam, hyena, tch, automaticity, reception, exterminated, chancellors,
# Nearest to resources: heine, malicious, virtually, maldivian, wars, detergent, judean, arson,
# Nearest to hold: testa, prescription, proc, comprehensible, giza, altruism, apotheosis, untrained,
# Nearest to something: aerobics, venn, vibrating, kingsley, cations, crag, repairs, renouf,
# Nearest to engineering: wintour, bornholm, footprints, cubism, bolden, sandow, denoting, quae,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 17.0416 0.1776 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 16.8351 0.1757 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 16.6854 0.1773 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 16.6637 0.1766 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 16.6223 0.1769 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 16.5164 0.1755 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 16.3524 0.1276 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 16.1053 0.1764 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 16.0396 0.1754 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 15.9325 0.1774 sec/batch
# Nearest to nine: nurse, ludwig, matured, micrometer, adh, westwood, albano, jabberwocky,
# Nearest to who: uns, sniper, judaean, mustelidae, boudinot, moldovans, decidable, merlin,
# Nearest to be: imre, sanjo, fantasy, gotta, mitigated, asu, min, chickpea,
# Nearest to over: digger, marianne, raoul, allergic, bulky, amakusa, bennie, perceiving,
# Nearest to called: although, faqs, reichsf, hadrian, antiparticle, liquidated, substitutions, gregorio,
# Nearest to where: wonders, insolence, seagulls, haystack, moscow, searing, dniester, landtag,
# Nearest to has: weu, contraction, escort, basquiat, graceful, etcetera, laureates, areal,
# Nearest to may: quezon, programme, peasants, revamped, miniseries, rounded, kook, hypermedia,
# Nearest to test: cali, signatories, adversity, chappell, jug, khanates, bildungsroman, barges,
# Nearest to police: unfaithful, headhunters, augustinian, dagan, despot, tarot, bioprospecting, ventricular,
# Nearest to square: white, practitioners, brixton, melodramatic, anduin, abuses, tip, hyun,
# Nearest to behind: exemplifies, noam, hyena, tch, reception, automaticity, chancellors, majed,
# Nearest to resources: heine, malicious, virtually, medication, maldivian, judean, arson, wars,
# Nearest to hold: testa, prescription, untrained, proc, comprehensible, apotheosis, giza, altruism,
# Nearest to something: aerobics, vibrating, cations, venn, kingsley, dvds, abunda, renouf,
# Nearest to engineering: wintour, bornholm, footprints, cubism, bolden, sandow, denoting, cooke,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 15.7491 0.1772 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 15.7180 0.1769 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 15.5361 0.1762 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 15.5441 0.1765 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 15.5172 0.1757 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 15.3815 0.1761 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 15.2869 0.1771 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 15.0738 0.1757 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 15.1388 0.1757 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 15.1263 0.1782 sec/batch
# Nearest to nine: or, and, micrometer, matured, ludwig, adh, westwood, nurse,
# Nearest to who: uns, sniper, a, judaean, decidable, narses, sieve, baseless,
# Nearest to be: imre, sanjo, asu, vowel, fantasy, chickpea, mitigated, person,
# Nearest to over: digger, marianne, raoul, allergic, secularism, bulky, consistent, bennie,
# Nearest to called: although, antiparticle, faqs, reichsf, gregorio, kneeling, hadrian, warms,
# Nearest to where: wonders, seagulls, insolence, dniester, haystack, moscow, aph, rapport,
# Nearest to has: escort, contraction, unce, basquiat, weu, pinocchio, graceful, fraud,
# Nearest to may: quezon, programme, revamped, peasants, kook, rounded, miniseries, abscess,
# Nearest to test: cali, barges, adversity, bildungsroman, varanus, signatories, popov, jug,
# Nearest to police: unfaithful, headhunters, dagan, despot, augustinian, bioprospecting, critically, tarot,
# Nearest to square: white, practitioners, routes, anduin, brixton, abuses, melodramatic, tip,
# Nearest to behind: exemplifies, noam, hyena, automaticity, tch, chancellors, reception, majed,
# Nearest to resources: heine, malicious, medication, virtually, maldivian, wars, arson, militarist,
# Nearest to hold: testa, proc, comprehensible, untrained, prescription, giza, apotheosis, altruism,
# Nearest to something: vibrating, aerobics, kingsley, cations, dvds, crag, venn, abunda,
# Nearest to engineering: wintour, bornholm, footprints, cubism, bolden, officialdom, poirot, sukkah,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 15.0787 0.1785 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 14.8817 0.1766 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 14.8540 0.1764 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 14.7170 0.1771 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 14.7423 0.1766 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 14.6924 0.1758 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 14.3556 0.1761 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 14.4950 0.1765 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 14.3425 0.1776 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 14.2657 0.1769 sec/batch
# Nearest to nine: three, one, zero, and, of, the, two, or,
# Nearest to who: of, two, uns, in, sniper, total, sieve, tourists,
# Nearest to be: imre, and, on, person, fantasy, asu, sanjo, with,
# Nearest to over: digger, marianne, raoul, allergic, secularism, bulky, amakusa, consistent,
# Nearest to called: although, reichsf, antiparticle, faqs, kneeling, concerto, warms, gregorio,
# Nearest to where: wonders, insolence, seagulls, dniester, aph, gunmen, memoir, haystack,
# Nearest to has: is, escort, it, of, in, the, fraud, weu,
# Nearest to may: quezon, programme, revamped, kook, peasants, biologists, miniseries, ladislaus,
# Nearest to test: cali, bildungsroman, barges, signatories, adversity, popov, chappell, varanus,
# Nearest to police: unfaithful, augustinian, dagan, headhunters, despot, tarot, bioprospecting, prosecutorial,
# Nearest to square: white, practitioners, anduin, routes, hyun, melodramatic, dorsal, brixton,
# Nearest to behind: hyena, exemplifies, noam, majed, automaticity, chancellors, reception, unreliability,
# Nearest to resources: heine, malicious, wars, arson, maldivian, virtually, magazines, medication,
# Nearest to hold: testa, proc, comprehensible, untrained, giza, prescription, apotheosis, handbook,
# Nearest to something: vibrating, aerobics, abunda, cations, dvds, crag, systematically, venn,
# Nearest to engineering: wintour, bornholm, footprints, cubism, bolden, sukkah, poirot, officialdom,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 14.3530 0.1793 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 14.2194 0.1767 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 13.9230 0.1766 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 14.0776 0.1760 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 13.9798 0.1802 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 13.7602 0.1818 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 13.7778 0.1795 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 13.7292 0.1794 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 13.5915 0.1804 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 13.5406 0.1807 sec/batch
# Nearest to nine: one, two, three, zero, eight, five, the, of,
# Nearest to who: in, is, with, a, and, by, two, of,
# Nearest to be: is, in, a, on, that, to, with, of,
# Nearest to over: digger, marianne, raoul, for, allergic, consistent, amakusa, on,
# Nearest to called: faqs, although, antiparticle, reichsf, kneeling, concerto, kovacs, pfalz,
# Nearest to where: wonders, insolence, dniester, s, seagulls, quadrennial, aph, memoir,
# Nearest to has: is, to, of, on, with, and, it, the,
# Nearest to may: quezon, a, programme, revamped, is, that, peasants, rounded,
# Nearest to test: cali, barges, varanus, relationship, bildungsroman, popov, adversity, chappell,
# Nearest to police: unfaithful, augustinian, dagan, headhunters, despot, bioprospecting, warmly, tarot,
# Nearest to square: white, practitioners, anduin, hyun, routes, dorsal, tip, brixton,
# Nearest to behind: hyena, noam, unreliability, exemplifies, majed, spontaneously, reception, automaticity,
# Nearest to resources: heine, wars, malicious, magazines, maldivian, dowling, virtually, cmb,
# Nearest to hold: testa, comprehensible, proc, giza, prescription, handbook, untrained, myspace,
# Nearest to something: vibrating, aerobics, dvds, cations, crag, tally, systematically, abunda,
# Nearest to engineering: wintour, bornholm, cubism, footprints, bolden, sukkah, poirot, tricky,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 13.4960 0.1803 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 13.5396 0.1798 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 13.4237 0.1808 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 13.4426 0.1804 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 13.3151 0.1787 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 13.0664 0.1806 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 13.2708 0.1799 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 13.2112 0.1790 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 12.8319 0.1793 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 12.9736 0.1808 sec/batch
# Nearest to nine: one, zero, eight, five, two, three, seven, six,
# Nearest to who: a, to, was, with, the, in, and, one,
# Nearest to be: that, to, this, is, for, a, and, with,
# Nearest to over: in, on, digger, marianne, crowns, first, amakusa, two,
# Nearest to called: were, although, february, faqs, venus, kneeling, it, pfalz,
# Nearest to where: wonders, is, in, that, or, a, to, experienced,
# Nearest to has: and, the, that, in, for, to, a, as,
# Nearest to may: a, an, in, the, for, that, or, with,
# Nearest to test: cali, varanus, barges, relationship, bildungsroman, chappell, rastislav, bandit,
# Nearest to police: unfaithful, augustinian, headhunters, dagan, despot, warmly, bioprospecting, tarot,
# Nearest to square: white, practitioners, anduin, hyun, copyrighted, bfa, costumed, hasidic,
# Nearest to behind: hyena, unreliability, exemplifies, noam, salish, reception, majed, exterminated,
# Nearest to resources: wars, heine, cmb, shame, magazines, conduction, medication, malicious,
# Nearest to hold: testa, comprehensible, proc, giza, handbook, prescription, untrained, myspace,
# Nearest to something: vibrating, cations, dvds, aerobics, crag, pickles, systematically, acclaim,
# Nearest to engineering: wintour, bornholm, bolden, footprints, cubism, poirot, tricky, officialdom,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 12.9176 0.1812 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 12.8298 0.1794 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 12.6515 0.0792 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 12.5771 0.1841 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 12.5817 0.1824 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 12.5012 0.1824 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 12.3625 0.1839 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 12.3308 0.1830 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 12.1286 0.1831 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 11.9863 0.1829 sec/batch
# Nearest to nine: one, eight, six, three, two, five, seven, four,
# Nearest to who: the, was, to, a, of, be, and, by,
# Nearest to be: of, is, to, the, that, in, or, a,
# Nearest to over: of, zero, be, two, in, three, four, first,
# Nearest to called: and, have, of, but, which, a, to, or,
# Nearest to where: the, in, be, to, is, for, a, with,
# Nearest to has: in, is, the, of, a, be, and, to,
# Nearest to may: of, that, the, to, as, be, a, in,
# Nearest to test: cali, varanus, barges, rastislav, farian, bandit, satellite, jug,
# Nearest to police: unfaithful, augustinian, dagan, headhunters, bioprospecting, despot, wakefield, warmly,
# Nearest to square: white, practitioners, anduin, infrequently, hasidic, hyun, brixton, tip,
# Nearest to behind: hyena, unreliability, salish, exemplifies, majed, noam, spontaneously, exterminated,
# Nearest to resources: wars, magazines, shame, heine, maldivian, cmb, fiji, secondary,
# Nearest to hold: testa, comprehensible, giza, handbook, prescription, subgroups, proc, altruism,
# Nearest to something: other, vibrating, acclaim, dvds, cations, venn, seventeenth, systematically,
# Nearest to engineering: wintour, bolden, footprints, bornholm, touchstone, sandow, tricky, cubism,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 12.1190 0.1841 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 12.0594 0.1825 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 11.9300 0.1833 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 11.6525 0.1850 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 11.7807 0.1843 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 11.7872 0.1834 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 11.7963 0.1820 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 11.7213 0.1835 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 11.5356 0.1828 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 11.5071 0.1835 sec/batch
# Nearest to nine: one, seven, zero, five, three, six, two, four,
# Nearest to who: his, to, with, the, in, was, of, he,
# Nearest to be: of, is, that, to, a, can, the, it,
# Nearest to over: for, a, as, has, in, of, and, at,
# Nearest to called: to, of, which, and, the, for, a, all,
# Nearest to where: to, the, a, of, this, from, is, other,
# Nearest to has: also, of, in, to, the, for, a, by,
# Nearest to may: the, that, is, to, not, of, as, or,
# Nearest to test: cali, varanus, barges, bandit, rastislav, satellite, amalgamated, farian,
# Nearest to police: unfaithful, augustinian, dagan, headhunters, deluxe, despot, warmly, wakefield,
# Nearest to square: white, infrequently, anduin, practitioners, hasidic, tip, hyun, heap,
# Nearest to behind: salish, unreliability, hyena, hereafter, exemplifies, majed, spontaneously, noam,
# Nearest to resources: magazines, shame, wars, maldivian, fiji, basis, secondary, dimbleby,
# Nearest to hold: testa, comprehensible, giza, myspace, jim, prescription, handbook, subgroups,
# Nearest to something: vibrating, venn, cations, crag, was, acclaim, possum, all,
# Nearest to engineering: wintour, touchstone, sandow, bolden, tricky, cubism, bornholm, carnivora,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 11.5630 0.1845 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 11.5792 0.1826 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 11.2261 0.1829 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 11.3169 0.1854 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 11.3165 0.1835 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 11.1465 0.1826 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 11.2573 0.1832 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 11.2326 0.1826 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 10.8556 0.1826 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 10.9844 0.1825 sec/batch
# Nearest to nine: one, four, three, seven, six, zero, five, eight,
# Nearest to who: was, his, that, and, in, the, he, be,
# Nearest to be: that, as, a, it, are, this, the, more,
# Nearest to over: for, the, years, in, from, of, to, two,
# Nearest to called: a, the, are, to, of, is, be, that,
# Nearest to where: the, a, in, that, it, or, this, to,
# Nearest to has: of, the, that, this, as, and, in, a,
# Nearest to may: a, be, or, to, of, are, in, not,
# Nearest to test: cali, barges, varanus, amalgamated, rastislav, g, farian, bivector,
# Nearest to police: unfaithful, augustinian, despot, erecting, wakefield, headhunters, prosecutorial, mockingly,
# Nearest to square: white, infrequently, whose, anduin, hasidic, uqbar, hyun, practitioners,
# Nearest to behind: unreliability, salish, majed, hyena, hereafter, noam, exterminated, chan,
# Nearest to resources: magazines, wars, shame, secondary, fiji, orazio, cmb, dowling,
# Nearest to hold: testa, giza, jim, will, myspace, comprehensible, nomenologie, believing,
# Nearest to something: to, but, soon, acclaim, vibrating, following, he, i,
# Nearest to engineering: wintour, tricky, bolden, spending, sandow, carnivora, sukkah, multi,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 11.1288 0.1855 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 10.8736 0.1833 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 10.8980 0.1824 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 10.8477 0.1823 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 10.7434 0.1832 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 10.5719 0.1831 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 10.5945 0.1820 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 10.7386 0.1825 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 10.6315 0.1825 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 10.5382 0.1825 sec/batch
# Nearest to nine: one, six, eight, five, seven, three, four, two,
# Nearest to who: his, the, of, was, a, had, he, that,
# Nearest to be: a, to, this, that, it, the, have, is,
# Nearest to over: the, in, to, were, a, that, for, on,
# Nearest to called: for, of, a, the, to, is, which, be,
# Nearest to where: a, this, the, with, for, that, if, there,
# Nearest to has: a, the, this, it, be, that, in, have,
# Nearest to may: a, in, that, be, an, to, are, more,
# Nearest to test: cali, amalgamated, varanus, barges, farian, satellite, g, rastislav,
# Nearest to police: unfaithful, augustinian, wakefield, erecting, mockingly, planned, theorize, bioprospecting,
# Nearest to square: white, infrequently, anduin, hasidic, whose, m, practitioners, phaenomena,
# Nearest to behind: unreliability, salish, majed, repeatedly, avionics, noam, exterminated, spontaneously,
# Nearest to resources: magazines, wars, land, shame, secondary, managing, orazio, settling,
# Nearest to hold: will, there, testa, have, however, left, did, large,
# Nearest to something: to, world, that, because, most, i, having, do,
# Nearest to engineering: wintour, bolden, sandow, spending, tricky, troyes, footprints, multi,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 10.7695 0.1841 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 10.2053 0.1820 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 10.5174 0.1819 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 10.3995 0.1826 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 10.0577 0.1815 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 10.3136 0.1819 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 10.2579 0.1824 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 10.1881 0.1810 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 10.2175 0.0294 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 9.9497 0.1814 sec/batch
# Nearest to nine: eight, one, six, three, seven, four, five, zero,
# Nearest to who: the, was, his, had, he, to, by, were,
# Nearest to be: that, to, is, the, any, a, this, or,
# Nearest to over: the, s, and, to, in, there, was, of,
# Nearest to called: is, the, to, of, it, have, there, been,
# Nearest to where: the, to, of, this, and, on, there, a,
# Nearest to has: to, all, and, the, is, a, in, of,
# Nearest to may: the, that, a, all, it, to, be, and,
# Nearest to test: cali, varanus, amalgamated, barges, satellite, g, farian, rastislav,
# Nearest to police: unfaithful, government, augustinian, erecting, elected, planned, support, mockingly,
# Nearest to square: white, infrequently, m, whose, either, salutary, kingdom, during,
# Nearest to behind: unreliability, salish, repeatedly, any, considered, followed, exemplifies, information,
# Nearest to resources: quite, high, well, land, in, magazines, basis, found,
# Nearest to hold: there, did, left, then, only, after, however, they,
# Nearest to something: to, which, but, given, up, has, all, those,
# Nearest to engineering: wintour, bolden, spending, sandow, tricky, footprints, poirot, sukkah,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 9.9747 0.1827 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 10.0801 0.1815 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 9.8167 0.1812 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 9.9508 0.1818 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 9.7418 0.1812 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 9.5236 0.1811 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 9.7248 0.1824 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 9.6586 0.1815 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 9.5996 0.1827 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 9.2513 0.1828 sec/batch
# Nearest to nine: one, six, two, seven, four, three, eight, five,
# Nearest to who: the, his, in, to, had, when, he, was,
# Nearest to be: a, of, the, is, to, it, that, and,
# Nearest to over: and, in, the, of, from, to, its, a,
# Nearest to called: of, and, the, for, are, it, to, as,
# Nearest to where: a, to, of, the, in, and, or, it,
# Nearest to has: the, of, in, its, and, a, that, have,
# Nearest to may: to, of, be, in, which, the, a, and,
# Nearest to test: cali, barges, amalgamated, usages, varanus, satellite, goldfinger, molasses,
# Nearest to police: support, elected, established, led, was, most, remain, government,
# Nearest to square: white, four, several, whether, five, m, kingdom, zero,
# Nearest to behind: use, considered, any, information, then, be, gain, if,
# Nearest to resources: position, land, quite, a, in, of, well, many,
# Nearest to hold: been, the, they, to, a, and, their, from,
# Nearest to something: little, those, on, them, most, either, be, but,
# Nearest to engineering: wintour, spending, bolden, nasir, peroxide, footprints, moderate, oversized,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 9.2888 0.1826 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 9.3801 0.1820 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 9.4731 0.1821 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 9.4966 0.1826 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 9.1891 0.1825 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 9.2787 0.1816 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 9.2922 0.1832 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 9.4156 0.1826 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 8.9573 0.1827 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 9.0588 0.1823 sec/batch
# Nearest to nine: seven, one, eight, three, six, four, two, zero,
# Nearest to who: and, in, was, he, had, to, being, with,
# Nearest to be: a, is, it, this, that, the, different, of,
# Nearest to over: to, and, the, in, for, it, from, a,
# Nearest to called: or, for, the, a, of, as, any, to,
# Nearest to where: the, and, to, of, so, is, or, it,
# Nearest to has: of, for, and, have, some, its, the, it,
# Nearest to may: a, of, to, this, not, with, it, is,
# Nearest to test: each, cali, barges, formed, decisions, goldfinger, ensure, amalgamated,
# Nearest to police: support, local, too, members, elected, remain, hard, clearly,
# Nearest to square: white, m, later, few, same, on, whether, four,
# Nearest to behind: developed, basis, third, some, of, called, to, any,
# Nearest to resources: and, has, of, directly, into, than, most, high,
# Nearest to hold: to, many, the, did, they, most, from, it,
# Nearest to something: but, would, a, it, there, be, of, being,
# Nearest to engineering: wintour, spending, bolden, shofar, nasir, moderate, owns, touchstone,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 9.0609 0.1833 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 9.0048 0.1822 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 9.0363 0.1826 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 9.0531 0.1823 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 8.8549 0.1824 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 8.7924 0.1817 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 9.0037 0.1814 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 8.7566 0.1827 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 8.7842 0.1824 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 8.8371 0.1847 sec/batch
# Nearest to nine: six, one, zero, seven, four, eight, five, three,
# Nearest to who: to, the, his, of, that, and, their, but,
# Nearest to be: is, it, a, this, for, to, that, any,
# Nearest to over: the, of, to, in, for, has, from, with,
# Nearest to called: is, the, only, or, a, for, this, it,
# Nearest to where: so, is, the, it, a, an, this, on,
# Nearest to has: of, for, a, the, have, in, it, by,
# Nearest to may: to, a, not, have, it, of, as, for,
# Nearest to test: require, ended, barges, cali, with, purchased, must, applied,
# Nearest to police: several, began, members, the, low, government, cases, was,
# Nearest to square: about, few, m, however, despite, year, zero, every,
# Nearest to behind: public, its, on, increased, developed, special, as, their,
# Nearest to resources: level, including, economic, within, more, most, large, today,
# Nearest to hold: many, their, a, to, that, there, for, the,
# Nearest to something: do, that, to, a, as, this, it, you,
# Nearest to engineering: wintour, bolden, spending, owns, shofar, nasir, multi, touchstone,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 8.8175 0.1828 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 8.5485 0.1809 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 8.5336 0.1824 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 8.6656 0.1820 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 8.7153 0.1835 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 8.6337 0.1816 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 8.7918 0.1778 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 8.3149 0.1794 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 8.5754 0.1785 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 8.6626 0.1790 sec/batch
# Nearest to nine: one, eight, seven, two, four, five, three, six,
# Nearest to who: his, he, in, the, and, was, to, as,
# Nearest to be: to, this, any, a, is, not, and, it,
# Nearest to over: the, and, of, in, to, by, were, has,
# Nearest to called: to, which, of, is, the, by, and, has,
# Nearest to where: the, to, in, of, a, and, on, called,
# Nearest to has: to, a, and, of, is, the, that, this,
# Nearest to may: and, to, it, a, have, of, the, this,
# Nearest to test: believed, performance, applied, with, for, where, ended, a,
# Nearest to police: which, for, members, currently, its, by, several, government,
# Nearest to square: area, where, to, are, about, however, at, is,
# Nearest to behind: the, then, as, all, on, his, and, of,
# Nearest to resources: level, economic, land, also, natural, industry, are, non,
# Nearest to hold: to, that, while, a, some, not, been, and,
# Nearest to something: not, that, them, what, to, you, a, as,
# Nearest to engineering: spending, mechanism, wintour, owns, bolden, nasir, school, touchstone,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 8.2976 0.1790 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 8.3191 0.1790 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 8.3793 0.1799 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 8.4256 0.1784 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 8.4820 0.1797 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 8.1347 0.1583 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 8.2550 0.1805 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 8.2726 0.1783 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 8.0882 0.1804 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 8.2074 0.1797 sec/batch
# Nearest to nine: one, seven, eight, six, four, three, american, five,
# Nearest to who: was, when, had, he, in, the, to, his,
# Nearest to be: have, a, can, to, that, for, or, an,
# Nearest to over: and, the, a, of, which, to, s, in,
# Nearest to called: to, is, have, are, some, a, for, the,
# Nearest to where: and, to, in, the, a, is, as, its,
# Nearest to has: a, have, the, for, to, as, in, an,
# Nearest to may: a, to, with, have, as, of, be, in,
# Nearest to test: this, a, require, very, size, different, note, began,
# Nearest to police: government, the, had, members, military, to, during, which,
# Nearest to square: area, m, two, number, approximately, zero, also, on,
# Nearest to behind: to, which, the, even, time, only, off, did,
# Nearest to resources: level, many, such, industry, for, has, use, high,
# Nearest to hold: to, that, a, which, their, of, with, were,
# Nearest to something: to, that, but, more, a, what, you, only,
# Nearest to engineering: mechanism, moderate, spending, classify, wintour, owns, touchstone, televisions,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 8.1138 0.1801 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.8330 0.1783 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 8.0309 0.1808 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 7.9687 0.1767 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 8.0203 0.1761 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.6473 0.1763 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 7.6323 0.1764 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.7793 0.1767 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.8001 0.1763 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.9620 0.1757 sec/batch
# Nearest to nine: one, seven, eight, three, five, six, four, zero,
# Nearest to who: his, he, had, was, first, the, their, them,
# Nearest to be: it, a, to, is, can, different, this, that,
# Nearest to over: and, the, of, were, people, by, to, since,
# Nearest to called: to, for, a, the, which, of, and, such,
# Nearest to where: the, to, of, is, and, in, a, with,
# Nearest to has: of, the, to, in, more, and, a, with,
# Nearest to may: to, be, not, that, which, has, this, the,
# Nearest to test: a, ability, provides, result, each, problems, particular, to,
# Nearest to police: government, army, military, was, in, attacks, during, war,
# Nearest to square: area, approximately, largest, city, m, has, zero, on,
# Nearest to behind: to, with, at, before, their, the, would, them,
# Nearest to resources: and, the, which, industry, has, of, growing, to,
# Nearest to hold: by, the, they, to, that, with, without, and,
# Nearest to something: as, to, not, be, that, a, they, it,
# Nearest to engineering: mechanism, moderate, aspects, classify, spending, lack, playing, relations,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 7.6932 0.1771 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.7804 0.1761 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.6714 0.1766 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.8487 0.1829 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.6492 0.1774 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 7.3499 0.1756 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 7.6330 0.1761 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 7.6802 0.1765 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 7.4807 0.1763 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.6150 0.1770 sec/batch
# Nearest to nine: one, seven, six, four, american, eight, three, zero,
# Nearest to who: his, was, he, of, the, and, had, their,
# Nearest to be: is, it, or, a, this, that, more, to,
# Nearest to over: to, the, and, in, a, on, for, of,
# Nearest to called: or, used, is, all, a, this, for, the,
# Nearest to where: a, when, than, is, more, it, be, to,
# Nearest to has: of, to, in, and, the, it, a, for,
# Nearest to may: a, be, it, or, is, that, to, this,
# Nearest to test: that, make, each, second, a, as, with, out,
# Nearest to police: forces, military, war, government, members, after, army, established,
# Nearest to square: area, approximately, city, m, places, every, line, notable,
# Nearest to behind: to, in, the, had, while, it, by, but,
# Nearest to resources: has, industry, and, economic, within, of, or, used,
# Nearest to hold: to, be, they, between, it, without, a, for,
# Nearest to something: that, so, but, to, this, as, a, it,
# Nearest to engineering: mechanism, same, classify, also, changed, concerned, taking, increasingly,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 7.4509 0.1776 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 7.3081 0.1787 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 7.5609 0.1764 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 7.4686 0.1760 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 7.4163 0.1763 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 7.4524 0.1769 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 7.5068 0.1764 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 7.0919 0.1770 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 7.2160 0.1764 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 7.2155 0.1766 sec/batch
# Nearest to nine: one, six, seven, eight, five, four, two, three,
# Nearest to who: was, his, of, in, he, had, s, the,
# Nearest to be: is, not, or, are, a, this, to, that,
# Nearest to over: the, and, of, to, with, in, by, at,
# Nearest to called: a, of, is, and, the, or, most, this,
# Nearest to where: a, that, the, is, this, to, and, in,
# Nearest to has: and, to, the, of, is, a, that, as,
# Nearest to may: to, that, a, not, is, for, be, with,
# Nearest to test: up, make, applied, a, has, which, can, is,
# Nearest to police: military, government, the, war, department, forces, world, during,
# Nearest to square: area, in, areas, the, at, sea, by, where,
# Nearest to behind: the, had, with, to, in, its, of, as,
# Nearest to resources: level, industry, natural, has, most, wide, economic, industrial,
# Nearest to hold: and, to, for, some, while, of, a, by,
# Nearest to something: that, this, not, is, do, it, to, a,
# Nearest to engineering: mechanism, professional, increasingly, same, probably, however, technical, physics,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 7.4295 0.1781 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 7.3391 0.1768 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 7.4642 0.1770 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 7.2968 0.1763 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 7.0605 0.1765 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 7.3713 0.1769 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 7.2062 0.1772 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 7.0379 0.1761 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 7.1169 0.1762 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 7.2457 0.1765 sec/batch
# Nearest to nine: one, seven, eight, six, four, five, three, two,
# Nearest to who: his, was, he, had, her, him, were, the,
# Nearest to be: that, not, any, or, to, is, this, will,
# Nearest to over: the, in, from, and, were, of, s, on,
# Nearest to called: a, is, to, of, for, as, this, all,
# Nearest to where: a, is, to, that, of, the, and, as,
# Nearest to has: and, as, to, of, with, a, all, it,
# Nearest to may: and, to, a, the, that, all, this, have,
# Nearest to test: to, only, up, different, however, other, that, could,
# Nearest to police: military, forces, government, war, defense, during, against, department,
# Nearest to square: miles, approximately, area, from, centre, the, where, second,
# Nearest to behind: the, and, at, a, by, while, with, up,
# Nearest to resources: industry, level, market, wide, high, natural, economic, are,
# Nearest to hold: that, to, not, for, and, some, they, while,
# Nearest to something: they, that, this, not, do, what, any, them,
# Nearest to engineering: physics, mechanism, technical, exact, scale, reflects, provided, advanced,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 7.1771 0.1776 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 7.0934 0.1063 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 7.0346 0.1774 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 7.1295 0.1762 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 7.0278 0.1763 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 6.9817 0.1769 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 7.0519 0.1763 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.9267 0.1776 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.7864 0.1766 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.9212 0.1762 sec/batch
# Nearest to nine: one, seven, eight, six, four, three, five, zero,
# Nearest to who: his, him, he, was, had, himself, when, the,
# Nearest to be: that, or, is, as, which, have, an, this,
# Nearest to over: its, in, and, the, years, of, zero, from,
# Nearest to called: is, of, an, as, and, many, this, to,
# Nearest to where: is, to, of, this, and, a, the, than,
# Nearest to has: of, the, for, and, its, in, an, to,
# Nearest to may: to, that, or, they, the, has, in, have,
# Nearest to test: make, this, development, been, however, well, a, result,
# Nearest to police: military, war, forces, political, army, civil, against, under,
# Nearest to square: miles, area, m, km, approximately, city, distance, largest,
# Nearest to behind: a, the, with, and, to, all, by, at,
# Nearest to resources: industry, level, services, has, environment, development, large, for,
# Nearest to hold: that, to, and, them, of, therefore, their, while,
# Nearest to something: that, not, they, like, but, someone, some, things,
# Nearest to engineering: mechanism, exact, physics, required, whereas, increasingly, difference, technical,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 6.9357 0.1765 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.6683 0.1761 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.5181 0.1766 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.7028 0.1776 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.7285 0.1758 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.8892 0.1770 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.7572 0.1757 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.6746 0.1769 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.6300 0.1758 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.8002 0.1761 sec/batch
# Nearest to nine: one, seven, eight, three, six, four, five, zero,
# Nearest to who: he, was, his, after, had, life, him, but,
# Nearest to be: a, is, it, that, this, can, any, are,
# Nearest to over: the, of, at, and, its, to, since, in,
# Nearest to called: is, for, or, of, it, to, be, are,
# Nearest to where: the, to, a, this, from, its, is, well,
# Nearest to has: to, of, in, the, for, however, from, and,
# Nearest to may: not, to, have, or, that, a, can, be,
# Nearest to test: a, the, control, other, would, to, however, of,
# Nearest to police: army, forces, war, armed, military, department, government, civil,
# Nearest to square: area, approximately, at, distance, miles, located, largest, between,
# Nearest to behind: before, a, the, their, and, to, s, they,
# ...
# Nearest to called: which, is, a, for, of, as, and, the,
# Nearest to where: a, when, to, this, it, with, the, and,
# Nearest to has: the, of, as, in, and, much, an, is,
# Nearest to may: has, they, or, that, to, have, not, some,
# Nearest to test: testing, tests, on, mission, scheduled, launched, performance, vehicle,
# Nearest to police: military, army, arrested, civilian, officers, war, killing, against,
# Nearest to square: mile, area, metres, largest, miles, km, situated, city,
# Nearest to behind: to, the, up, with, out, end, time, but,
# Nearest to resources: industry, resource, export, extensive, information, services, developing, providing,
# Nearest to hold: that, them, to, not, give, they, accept, persons,
# Nearest to something: anything, what, not, that, like, someone, you, idea,
# Nearest to engineering: research, engineers, electrical, electronics, educational, science, technical, students,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 5.0243 0.1773 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.9150 0.1754 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 5.0179 0.1755 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 5.0542 0.1756 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.1696 0.1748 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 5.0864 0.1750 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.0829 0.1755 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 5.0405 0.1753 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.1712 0.1760 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.1687 0.1751 sec/batch
# Nearest to nine: one, eight, four, seven, three, six, american, two,
# Nearest to who: he, his, her, she, him, had, himself, love,
# Nearest to be: can, a, is, or, that, to, this, any,
# Nearest to over: the, its, since, for, of, and, in, has,
# Nearest to called: is, or, the, which, are, a, only, example,
# Nearest to where: the, a, to, then, each, is, when, at,
# Nearest to has: in, for, of, the, and, which, a, also,
# Nearest to may: is, this, be, can, a, or, that, while,
# Nearest to test: a, testing, tests, performance, run, program, for, designed,
# Nearest to police: army, military, officers, war, officials, killing, responsibility, civilian,
# Nearest to square: metres, mile, area, miles, km, located, situated, approximately,
# Nearest to behind: with, the, when, so, before, on, up, time,
# Nearest to resources: resource, information, industry, export, economy, tourism, industries, mining,
# Nearest to hold: give, they, when, view, by, while, it, or,
# Nearest to something: not, anything, might, what, that, do, things, how,
# Nearest to engineering: research, engineers, institute, management, educational, sciences, technical, science,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.9156 0.1769 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 5.0533 0.1750 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.0760 0.1756 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 5.0040 0.1753 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.0766 0.1761 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 5.0378 0.1749 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.9169 0.1748 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.0469 0.1756 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 5.1049 0.1751 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 5.0114 0.1756 sec/batch
# Nearest to nine: four, one, eight, zero, seven, six, two, three,
# Nearest to who: his, he, her, him, she, was, whom, had,
# Nearest to be: that, is, this, can, are, any, only, may,
# Nearest to over: the, in, were, its, under, two, on, total,
# Nearest to called: is, are, or, all, be, a, it, and,
# Nearest to where: a, then, is, all, the, with, an, than,
# Nearest to has: the, to, its, other, in, of, however, and,
# Nearest to may: not, be, or, a, only, that, more, are,
# Nearest to test: testing, tests, can, results, make, run, a, designed,
# Nearest to police: military, officers, civilian, army, forces, officials, against, officer,
# Nearest to square: area, located, mile, situated, miles, metres, approximately, distance,
# Nearest to behind: out, start, contact, catch, once, their, ends, on,
# Nearest to resources: resource, information, includes, use, industry, development, research, markets,
# Nearest to hold: not, accept, some, whether, take, which, for, give,
# Nearest to something: that, anything, what, does, how, someone, you, do,
# Nearest to engineering: engineers, research, technical, electronics, applications, institute, management, laboratories,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 5.0385 0.1758 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 5.0581 0.1744 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.8570 0.1757 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.9196 0.1752 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.9295 0.1750 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.9687 0.1771 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 5.0666 0.1749 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.1887 0.1756 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.1586 0.1784 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.8731 0.1755 sec/batch
# Nearest to nine: one, eight, two, seven, four, six, three, five,
# Nearest to who: his, had, he, whom, was, by, him, himself,
# Nearest to be: this, that, any, it, not, is, or, if,
# Nearest to over: the, world, and, years, zero, since, in, population,
# Nearest to called: is, of, all, and, only, other, which, this,
# Nearest to where: then, the, in, a, at, left, there, which,
# Nearest to has: with, of, and, for, a, however, the, are,
# Nearest to may: to, for, an, have, with, that, it, a,
# Nearest to test: testing, tests, results, improvement, problems, requirements, nuclear, effects,
# Nearest to police: military, civilian, army, officers, officials, during, war, armed,
# Nearest to square: area, miles, mile, located, situated, near, approximately, southwest,
# Nearest to behind: up, down, the, hit, ground, only, had, once,
# Nearest to resources: markets, natural, economy, mining, oil, resource, export, agricultural,
# Nearest to hold: not, all, be, having, accept, for, that, may,
# Nearest to something: does, anything, you, what, someone, not, true, so,
# Nearest to engineering: engineers, research, technology, electronics, technical, laboratories, institute, systems,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.9689 0.1760 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.9861 0.1758 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.8376 0.1758 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.9029 0.1764 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.9596 0.1753 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.9735 0.1758 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 5.0146 0.0841 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.8813 0.1756 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.9222 0.1753 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.9588 0.1747 sec/batch
# Nearest to nine: one, eight, seven, four, six, two, american, three,
# Nearest to who: he, him, his, was, her, had, whom, of,
# Nearest to be: or, that, to, can, not, it, any, if,
# Nearest to over: the, from, to, its, since, and, up, years,
# Nearest to called: is, as, or, be, a, only, are, which,
# Nearest to where: in, a, is, the, to, there, which, and,
# Nearest to has: more, many, a, also, is, and, for, other,
# Nearest to may: for, or, as, a, not, with, be, has,
# Nearest to test: testing, tested, mission, scheduled, program, launch, tests, achieved,
# Nearest to police: officers, killing, army, military, arrested, guard, officer, defense,
# Nearest to square: miles, metres, area, mile, km, distance, feet, length,
# Nearest to behind: up, when, down, away, once, hit, had, after,
# Nearest to resources: economy, resource, sector, mining, industry, growing, products, development,
# Nearest to hold: that, to, not, with, accept, a, for, would,
# Nearest to something: you, that, anything, things, do, does, someone, know,
# Nearest to engineering: research, engineers, mechanical, institute, technology, technical, electrical, electronics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.8349 0.1760 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.9750 0.1745 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.8431 0.1749 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.7121 0.1745 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.8749 0.1752 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.9103 0.1753 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.8357 0.1762 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.6604 0.1759 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.7526 0.1752 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.7795 0.1752 sec/batch
# Nearest to nine: one, eight, seven, six, four, zero, three, five,
# Nearest to who: him, he, whom, his, their, had, they, was,
# Nearest to be: can, is, therefore, that, it, this, which, not,
# Nearest to over: and, the, in, of, under, two, its, between,
# Nearest to called: is, which, are, number, or, a, be, as,
# Nearest to where: a, the, is, at, from, and, then, there,
# Nearest to has: the, of, in, and, its, on, to, a,
# Nearest to may: not, this, are, that, to, be, as, a,
# Nearest to test: testing, designed, tests, on, a, problems, scheduled, program,
# Nearest to police: killing, army, officers, military, arrested, terrorist, federal, defense,
# Nearest to square: metres, mile, area, km, miles, located, feet, city,
# Nearest to behind: before, up, last, ground, after, out, fire, down,
# Nearest to resources: economy, extensive, resource, mining, industry, areas, growing, markets,
# Nearest to hold: that, their, to, being, call, them, having, necessary,
# Nearest to something: you, do, things, might, what, anything, experience, look,
# Nearest to engineering: research, engineers, technology, fields, systems, institute, science, technical,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.8489 0.1759 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.8428 0.1752 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.7650 0.1745 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.7493 0.1740 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.8348 0.1759 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.8931 0.1750 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.7159 0.1757 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.7139 0.1750 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.8110 0.1757 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.7511 0.1751 sec/batch
# Nearest to nine: one, seven, zero, eight, four, six, two, five,
# Nearest to who: he, his, him, her, was, after, she, had,
# Nearest to be: to, is, may, that, this, can, a, it,
# Nearest to over: to, its, under, the, two, following, in, for,
# Nearest to called: is, the, for, or, all, are, as, which,
# Nearest to where: is, a, the, when, then, left, with, in,
# Nearest to has: the, in, of, its, and, for, most, on,
# Nearest to may: be, not, is, does, are, any, cases, or,
# Nearest to test: testing, results, tests, tested, engine, a, can, problems,
# Nearest to police: military, civilian, officers, killing, forces, officials, arrested, army,
# Nearest to square: metres, area, distance, adjacent, approximately, length, map, km,
# Nearest to behind: catch, start, up, out, players, after, off, once,
# Nearest to resources: extensive, resource, economy, markets, agricultural, development, related, mining,
# Nearest to hold: not, to, be, does, without, must, call, take,
# Nearest to something: anything, that, how, might, do, things, what, not,
# Nearest to engineering: engineers, research, technology, technical, institute, science, computer, design,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.8000 0.1768 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.7848 0.1756 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.6262 0.1771 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.7667 0.1755 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.8382 0.1756 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.7595 0.1758 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.6977 0.1764 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.8084 0.1766 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.6684 0.1764 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.6408 0.1751 sec/batch
# Nearest to nine: four, one, six, three, eight, seven, zero, five,
# Nearest to who: he, his, him, himself, whom, her, their, never,
# Nearest to be: not, is, this, any, that, a, may, only,
# Nearest to over: of, in, the, by, with, to, its, from,
# Nearest to called: is, a, and, only, the, of, or, are,
# Nearest to where: is, the, so, are, a, then, in, with,
# Nearest to has: and, have, the, a, in, with, of, for,
# Nearest to may: to, be, not, a, any, is, for, have,
# Nearest to test: testing, tests, results, tested, performance, can, ability, problems,
# Nearest to police: military, officers, civilian, army, officials, forces, government, defence,
# Nearest to square: area, intersection, miles, mile, approximately, map, boundary, at,
# Nearest to behind: out, had, ends, end, start, back, lost, up,
# Nearest to resources: resource, markets, information, industry, extensive, projects, development, economy,
# Nearest to hold: their, acts, citizens, accept, judgment, be, without, what,
# Nearest to something: do, anything, things, does, what, that, you, someone,
# Nearest to engineering: research, engineers, institute, technology, electrical, electronics, technical, applications,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.7042 0.1777 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.6774 0.1763 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.7722 0.1754 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.8440 0.1758 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.9701 0.1752 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.6377 0.1757 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.7495 0.1753 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.6964 0.1757 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.5074 0.1759 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.6828 0.1756 sec/batch
# Nearest to nine: one, seven, eight, four, six, zero, two, five,
# Nearest to who: his, was, he, him, had, whom, himself, as,
# Nearest to be: that, or, so, this, to, it, not, a,
# Nearest to over: years, the, under, zero, has, total, s, two,
# Nearest to called: is, the, of, a, or, different, are, as,
# Nearest to where: is, the, with, a, to, it, at, point,
# Nearest to has: and, in, the, with, of, as, to, most,
# Nearest to may: or, be, for, is, to, a, any, are,
# Nearest to test: testing, tests, results, nuclear, problems, model, research, laboratory,
# Nearest to police: officers, military, army, forces, officials, guard, personnel, civilian,
# Nearest to square: area, miles, mile, approximately, where, metres, near, distance,
# Nearest to behind: down, hit, catch, up, chance, back, again, round,
# Nearest to resources: resource, mining, industry, natural, markets, development, land, economy,
# Nearest to hold: not, that, all, to, some, without, what, accept,
# Nearest to something: what, know, you, that, why, sense, mind, do,
# Nearest to engineering: research, institute, engineers, technology, science, electrical, electronics, sciences,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.7065 0.1767 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.6542 0.1755 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
